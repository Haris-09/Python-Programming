# %% [markdown]
# <a href="https://colab.research.google.com/github/Haris-09/Python-Programming/blob/main/Exploratory_Data_Analysis.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import pandas as pd

file_path = '/content/drive/My Drive/NAVTCC: Data Science & AI' # Replace with your file path
books = pd.read_csv(file_path+'/books_01.csv')
books.head()
# Out:
#                       Title            Author              Genre  Height  \
# 0  Fundamentals of Wavelets  Goswami, Jaideva  signal_processing     228
# 1                Data Smart     Foreman, John       data_science     235
# 2  God Created the Integers  Hawking, Stephen        mathematics     197
# 3         Superfreakonomics   Dubner, Stephen          economics     179
# 4               Orientalism      Said, Edward            history     197
#
#        Publisher  Ratings
# 0          Wiley      4.9
# 1          Wiley      1.2
# 2        Penguin      1.8
# 3  HarperCollins      1.8
# 4        Penguin      4.3

# %%
# How many types of Books we have
books.Genre.unique()
# Out:
# array(['signal_processing', 'data_science', 'mathematics', 'economics',
#        'history', 'science', 'psychology', 'fiction', 'computer_science',
#        'nonfiction', 'philosophy', 'comic'], dtype=object)

# %%
books.Genre.nunique()
# Out:
# 12

# %%
books.describe()
# Out:
#            Height     Ratings
# count  211.000000  211.000000
# mean   206.056872    2.971564
# std     26.828141    1.099111
# min    160.000000    1.000000
# 25%    180.000000    2.100000
# 50%    199.000000    3.000000
# 75%    229.500000    3.900000
# max    283.000000    5.000000

# %%
# How many books are there in each category of Genre
books.Genre.value_counts()
# Out:
# Genre
# fiction              64
# nonfiction           30
# history              26
# data_science         17
# philosophy           17
# science              14
# comic                13
# computer_science     11
# economics            10
# mathematics           5
# signal_processing     3
# psychology            1
# Name: count, dtype: int64

# %%
# Average grading of each category in genre
books.groupby('Genre')['Ratings'].mean()
# Out:
# Genre
# comic                2.915385
# computer_science     2.900000
# data_science         2.958824
# economics            2.820000
# fiction              2.923437
# history              2.719231
# mathematics          2.800000
# nonfiction           3.310000
# philosophy           3.211765
# psychology           2.200000
# science              2.692857
# signal_processing    4.366667
# Name: Ratings, dtype: float64

# %%
books.groupby('Genre').agg(
    grp_mean = ('Ratings', 'mean'),
    grp_std = ('Ratings', 'std'),
    grp_median = ('Ratings', 'median')
    )
# Out:
#                    grp_mean   grp_std  grp_median
# Genre
# comic              2.915385  1.240864        2.90
# computer_science   2.900000  1.224745        2.50
# data_science       2.958824  1.041669        3.10
# economics          2.820000  1.242578        3.00
# fiction            2.923437  1.156314        3.10
# history            2.719231  0.909074        2.60
# mathematics        2.800000  0.891628        3.10
# nonfiction         3.310000  1.114590        3.15
# philosophy         3.211765  1.064121        3.60
# psychology         2.200000       NaN        2.20
# science            2.692857  0.957131        2.50
# signal_processing  4.366667  0.550757        4.40

# %%
import seaborn as sns
import matplotlib.pyplot as plt
sns.histplot(data=books, x='Ratings', binwidth=0.1)
plt.show()

# %%
books['Ratings'] = books['Ratings'].astype(int)
books.dtypes
# Out:
# Title        object
# Author       object
# Genre        object
# Height        int64
# Publisher    object
# Ratings       int64
# dtype: object

# %%
books[books['Genre'].isin(['fiction', 'comic'])]
# Out:
#                                      Title               Author    Genre  \
# 11                     Slaughterhouse Five       Vonnegut, Kurt  fiction
# 15                              Trial, The         Kafka, Frank  fiction
# 18                    New Machiavelli, The         Wells, H. G.  fiction
# 27                           Outsider, The        Camus, Albert  fiction
# 28   Complete Sherlock Holmes, The - Vol I  Doyle, Arthur Conan  fiction
# ..                                     ...                  ...      ...
# 203              Girl who played with Fire       Larsson, Steig  fiction
# 204                        Batman Handbook                  NaN    comic
# 208                            Animal Farm       Orwell, George  fiction
# 209                             Idiot, The   Dostoevsky, Fyodor  fiction
# 210                     Christmas Carol, A     Dickens, Charles  fiction
#
#      Height     Publisher  Ratings
# 11      198  Random House        4
# ...

# %%
books = pd.read_csv(file_path+'/books_01.csv')

# %%
books.columns
# Out:
# Index(['Title', 'Author', 'Genre', 'Height', 'Publisher', 'Ratings'], dtype='object')

# %%
books[books['Genre'].isin(['fiction', 'nonfiction'])]
# Out:
#                              Title              Author       Genre  Height  \
# 11             Slaughterhouse Five      Vonnegut, Kurt     fiction     198
# 15                      Trial, The        Kafka, Frank     fiction     198
# 18            New Machiavelli, The        Wells, H. G.     fiction     180
# 26   Beautiful and the Damned, The     Deb, Siddhartha  nonfiction     198
# 27                   Outsider, The       Camus, Albert     fiction     198
# ..                             ...                 ...         ...     ...
# 203      Girl who played with Fire      Larsson, Steig     fiction     179
# 205                   Murphy's Law                 NaN  nonfiction     178
# 208                    Animal Farm      Orwell, George     fiction     180
# 209                     Idiot, The  Dostoevsky, Fyodor     fiction     197
# 210             Christmas Carol, A    Dickens, Charles     fiction     196
#
#         Publisher  Ratings
# 11   Random House      4.0
# ...

# %%
# only show numerical columns
books.select_dtypes("number").head()
# Out:
#    Height  Ratings
# 0     228      4.9
# 1     235      1.2
# 2     197      1.8
# 3     179      1.8
# 4     197      4.3

# %%
# only show categorical columns
books.select_dtypes(exclude="number").head()
# Out:
#                       Title            Author              Genre  \
# 0  Fundamentals of Wavelets  Goswami, Jaideva  signal_processing
# 1                Data Smart     Foreman, John       data_science
# 2  God Created the Integers  Hawking, Stephen        mathematics
# 3         Superfreakonomics   Dubner, Stephen          economics
# 4               Orientalism      Said, Edward            history
#
#        Publisher
# 0          Wiley
# 1          Wiley
# 2        Penguin
# 3  HarperCollins
# 4        Penguin

# %%
sns.boxplot(x='Ratings', y='Genre', data=books, palette='viridis', hue='Genre')
# Out:
# <Axes: xlabel='Ratings', ylabel='Genre'>

# %%
books.groupby('Genre')['Ratings'].agg([np.mean, np.std, np.median])
# Out:
# <ipython-input-19-3408499937>:1: FutureWarning: The provided callable <function mean at 0x7b634e3862a0> is currently using SeriesGroupBy.mean. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "mean" instead.
#   books.groupby('Genre')['Ratings'].agg([np.mean, np.std, np.median])
# <ipython-input-19-3408499937>:1: FutureWarning: The provided callable <function std at 0x7b634e3863e0> is currently using SeriesGroupBy.std. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "std" instead.
#   books.groupby('Genre')['Ratings'].agg([np.mean, np.std, np.median])
# <ipython-input-19-3408499937>:1: FutureWarning: The provided callable <function median at 0x7b634b123560> is currently using SeriesGroupBy.median. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "median" instead.
# ...

# %%
books.groupby('Genre')['Ratings'].agg(["mean", "std", "median"])
# Out:
#                        mean       std  median
# Genre
# comic              2.915385  1.240864    2.90
# computer_science   2.900000  1.224745    2.50
# data_science       2.958824  1.041669    3.10
# economics          2.820000  1.242578    3.00
# fiction            2.923437  1.156314    3.10
# history            2.719231  0.909074    2.60
# mathematics        2.800000  0.891628    3.10
# nonfiction         3.310000  1.114590    3.15
# philosophy         3.211765  1.064121    3.60
# psychology         2.200000       NaN    2.20
# science            2.692857  0.957131    2.50
# signal_processing  4.366667  0.550757    4.40

# %%
# splitting numerical and categorical columns
books_numerical=books.select_dtypes("number")
books_categorical=books.select_dtypes(exclude="number")

# %%
numerical_col_names=books_numerical.columns
categorical_col_names=books_categorical.columns

# %%
# replacing numerical data columns with the mean
for column in numerical_col_names:
    books[column].fillna(books[column].mean(), inplace=True)
# Out:
# <ipython-input-23-2109094293>:3: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   books[column].fillna(books[column].mean(), inplace=True)

# %%
books_numerical.agg(["mean", "std", "median"])
# Out:
#             Height   Ratings
# mean    206.056872  2.971564
# std      26.828141  1.099111
# median  199.000000  3.000000

# %%
books_categorical.agg(["mode"])
# Out:
#              Title           Author    Genre Publisher
#               mode             mode     mode      mode
# 0  Angels & Demons  Steinbeck, John  fiction   Penguin

# %%
books.groupby('Genre')['Ratings'].count()
# Out:
# Genre
# comic                13
# computer_science     11
# data_science         17
# economics            10
# fiction              64
# history              26
# mathematics           5
# nonfiction           30
# philosophy           17
# psychology            1
# science              14
# signal_processing     3
# Name: Ratings, dtype: int64

# %%
books.groupby('Genre')['Ratings'].max()
# Out:
# Genre
# comic                4.8
# computer_science     4.9
# data_science         4.8
# economics            4.3
# fiction              4.9
# history              4.5
# mathematics          3.6
# nonfiction           5.0
# philosophy           4.6
# psychology           2.2
# science              4.6
# signal_processing    4.9
# Name: Ratings, dtype: float64

# %%
books.agg(
    {
        'Height':['mean','std'],
        'Ratings':['median']
    }
)
# Out:
#             Height  Ratings
# mean    206.056872      NaN
# std      26.828141      NaN
# median         NaN      3.0

# %%
books.groupby('Genre').agg(
    mean_rating=('Ratings', 'mean'),
    std_rating=('Ratings', 'std'),
    median_rating=('Ratings', 'median')
)
# Out:
#                    mean_rating  std_rating  median_rating
# Genre
# comic                 2.915385    1.240864           2.90
# computer_science      2.900000    1.224745           2.50
# data_science          2.958824    1.041669           3.10
# economics             2.820000    1.242578           3.00
# fiction               2.923437    1.156314           3.10
# history               2.719231    0.909074           2.60
# mathematics           2.800000    0.891628           3.10
# nonfiction            3.310000    1.114590           3.15
# philosophy            3.211765    1.064121           3.60
# psychology            2.200000         NaN           2.20
# science               2.692857    0.957131           2.50
# signal_processing     4.366667    0.550757           4.40

# %%
sns.barplot(y='Genre', x='Ratings', data=books, palette='viridis', hue='Genre')
# Out:
# <Axes: xlabel='Ratings', ylabel='Genre'>

# %%
salaries = pd.read_csv(file_path+'/salary_data.csv')
salaries.head()
# Out:
#    Working_Year       Designation Experience Employment_Status  \
# 0        2020.0      Data Analyst       Lead                PT
# 1        2021.0  Business Analyst     Senior                FT
# 2        2023.0               NaN     Junior          Contract
# 3        2021.0  Business Analyst     Junior                FT
# 4        2024.0    Data Scientist       Lead                FT
#
#   Employee_Location Company_Size  Remote_Working_Ratio  Salary_USD
# 0           Germany            M                   0.0         NaN
# 1                UK            L                   0.0    53320.87
# 2                UK          NaN                 100.0         NaN
# 3           Germany            S                 100.0    55682.63
# 4               USA            S                 100.0    69469.78

# %%
sns.boxplot(x='Experience', y='Salary_USD', data=salaries, palette='viridis', hue='Experience')
# Out:
# <Axes: xlabel='Experience', ylabel='Salary_USD'>

# %%
salaries.isna().sum()
# Out:
# Working_Year            12
# Designation             42
# Experience              48
# Employment_Status       31
# Employee_Location       42
# Company_Size            40
# Remote_Working_Ratio    24
# Salary_USD              71
# dtype: int64

# %%
len(salaries)
# Out:
# 500

# %%
threshold = 45
column_to_remove = salaries.isna().sum()>=threshold
print(column_to_remove)
# Out:
# Working_Year            False
# Designation             False
# Experience               True
# Employment_Status       False
# Employee_Location       False
# Company_Size            False
# Remote_Working_Ratio    False
# Salary_USD               True
# dtype: bool

# %%
# use one of the lines below to remove the columns which contains empty values above threshold both logics works
# salaries = salaries.drop(columns=column_to_remove[column_to_remove].index)
salaries = salaries.drop(columns=salaries.columns[column_to_remove])
print(salaries.isna().sum())
# Out:
# Working_Year            12
# Designation             42
# Employment_Status       31
# Employee_Location       42
# Company_Size            40
# Remote_Working_Ratio    24
# dtype: int64

# %%
numerical_cloumns = salaries.select_dtypes("number").columns
print(numerical_cloumns)
# Out:
# Index(['Working_Year', 'Remote_Working_Ratio'], dtype='object')

# %%
categorical_cloumns = salaries.select_dtypes(exclude="number").columns
print(categorical_cloumns)
# Out:
# Index(['Designation', 'Employment_Status', 'Employee_Location',
#        'Company_Size'],
#       dtype='object')

# %%
# fill the missing values with mode for categorical columns
for column in categorical_cloumns:
    salaries[column] = salaries[column].fillna(salaries[column].mode()[0])

# %%
# fill the missing values with mean for numerical columns
for column in numerical_cloumns:
    salaries[column] = salaries[column].fillna(salaries[column].mean())

# %%
print(salaries.isna().sum())
# Out:
# Working_Year            0
# Designation             0
# Employment_Status       0
# Employee_Location       0
# Company_Size            0
# Remote_Working_Ratio    0
# dtype: int64

# %%
# mode doesn't work in groupby function as it can return multiple values so used the lambda function in agg function
salaries.groupby('Employment_Status')[categorical_cloumns].agg(lambda x: x.mode().iloc[0] if not x.mode().empty else None)
# Out:
#                         Designation Employment_Status Employee_Location  \
# Employment_Status
# Contract           Business Analyst          Contract                UK
# FT                 Business Analyst                FT            Canada
# PT                   Data Scientist                PT             India
#
#                   Company_Size
# Employment_Status
# Contract                     L
# FT                           L
# PT                           M

# %%
salary_dict = salaries.groupby('Employment_Status')['Working_Year'].mean().to_dict()
print(salary_dict)
# Out:
# {'Contract': 2019.590909090909, 'FT': 2019.7716039212455, 'PT': 2019.4761904761904}

# %%
salaries['Working_Year'] = salaries['Working_Year'].fillna(salaries['Employment_Status'].map(salary_dict))

# %%
salaries['Designation'].value_counts()
# Out:
# Designation
# Business Analyst             131
# Machine Learning Engineer     87
# Data Scientist                81
# Data Analyst                  75
# AI Researcher                 69
# Data Engineer                 57
# Name: count, dtype: int64

# %%
print(salaries['Designation'].nunique())
# Out:
# 6

# %%
# top 5 designations bar plot
top_5_designations = salaries['Designation'].value_counts().nlargest(5)
plt.figure(figsize=(10, 6))
sns.barplot(x=top_5_designations.index, y=top_5_designations.values, palette='viridis', hue=top_5_designations.index)
plt.title('Top 5 Designations by Count')
plt.xlabel('Designation')
plt.ylabel('Count')
plt.xticks(rotation=45, ha='right')
plt.tight_layout()
plt.show()

# %%
top_4 = salaries['Designation'].value_counts().head(4).reset_index()
print(top_4)
# Out:
#                  Designation  count
# 0           Business Analyst    131
# 1  Machine Learning Engineer     87
# 2             Data Scientist     81
# 3               Data Analyst     75

# %%
# top 4 designations bar plot
sns.barplot(data=top_4, x='Designation',  y='count', palette='viridis', hue='count')
plt.title('Top 4 Designations by Count')
plt.xlabel('Designation')
plt.ylabel('Count')
plt.xticks(rotation=45, ha='right')
plt.tight_layout()
plt.show()

# %%
salaries.Designation.str.contains('Data')
# Out:
# 0       True
# 1      False
# 2      False
# 3      False
# 4       True
#        ...
# 495    False
# 496     True
# 497    False
# 498     True
# 499    False
# Name: Designation, Length: 500, dtype: bool

# %%
# filer rows with designation contains word Data
salaries[salaries.Designation.str.contains('Data')]
# Out:
#      Working_Year     Designation Employment_Status Employee_Location  \
# 0          2020.0    Data Analyst                PT           Germany
# 4          2024.0  Data Scientist                FT               USA
# 8          2015.0   Data Engineer          Contract         Australia
# 14         2021.0  Data Scientist                FT               USA
# 15         2024.0  Data Scientist          Contract                UK
# ..            ...             ...               ...               ...
# 492        2021.0   Data Engineer          Contract            Canada
# 493        2024.0  Data Scientist                PT                UK
# 494        2024.0  Data Scientist          Contract               USA
# 496        2015.0  Data Scientist          Contract               USA
# 498        2019.0  Data Scientist                PT             India
#
#     Company_Size  Remote_Working_Ratio
# 0              M                   0.0
# 4              S                 100.0
# ...

# %%
salaries.Designation.str.contains('^Data')
# Out:
# 0       True
# 1      False
# 2      False
# 3      False
# 4       True
#        ...
# 495    False
# 496     True
# 497    False
# 498     True
# 499    False
# Name: Designation, Length: 500, dtype: bool

# %%
# filer rows with designation starts with Data
salaries[salaries.Designation.str.contains('^Data')]
# Out:
#      Working_Year     Designation Employment_Status Employee_Location  \
# 0          2020.0    Data Analyst                PT           Germany
# 4          2024.0  Data Scientist                FT               USA
# 8          2015.0   Data Engineer          Contract         Australia
# 14         2021.0  Data Scientist                FT               USA
# 15         2024.0  Data Scientist          Contract                UK
# ..            ...             ...               ...               ...
# 492        2021.0   Data Engineer          Contract            Canada
# 493        2024.0  Data Scientist                PT                UK
# 494        2024.0  Data Scientist          Contract               USA
# 496        2015.0  Data Scientist          Contract               USA
# 498        2019.0  Data Scientist                PT             India
#
#     Company_Size  Remote_Working_Ratio
# 0              M                   0.0
# 4              S                 100.0
# ...

# %%
df2 = pd.DataFrame({
    'scores': [23,56,90]
})
print(df2)

conditions=[
    df2['scores']>90,
    df2['scores']>50,
    df2['scores']>30
]

outcomes=['Excellent','Satisfactory','Average']

df2['Remarks']=np.select(conditions,outcomes,default='Poor')
print(df2)
# Out:
#    scores
# 0      23
# 1      56
# 2      90
#    scores       Remarks
# 0      23          Poor
# 1      56  Satisfactory
# 2      90  Satisfactory

# %%
job_categories = ['Data Science', 'Data Analytics', 'Data Engineering', 'Machine Learning', 'Managerial', 'Consultant']

data_science = "Data Scientist|NLP"
data_analyst = "Analyst|Analytics"
data_engineer = "Data Engineer|ETL|Arcitect|Infrastructure"
ml_engineer = "Machine Learning|ML|Big Data|AI"
manager = "Manager|Head|Director|Lead|Principle"
consultant = "Consultant"

conditions = [
    (salaries['Designation'].str.contains(data_science)),
    (salaries['Designation'].str.contains(data_analyst)),
    (salaries['Designation'].str.contains(data_engineer)),
    (salaries['Designation'].str.contains(ml_engineer)),
    (salaries['Designation'].str.contains(manager)),
    (salaries['Designation'].str.contains(consultant))
]

salaries['Job_Categories'] = np.select(conditions, job_categories, default='Other')

# %%
salaries.head()
# Out:
#    Working_Year       Designation Employment_Status Employee_Location  \
# 0        2020.0      Data Analyst                PT           Germany
# 1        2021.0  Business Analyst                FT                UK
# 2        2023.0  Business Analyst          Contract                UK
# 3        2021.0  Business Analyst                FT           Germany
# 4        2024.0    Data Scientist                FT               USA
#
#   Company_Size  Remote_Working_Ratio  Job_Categories
# 0            M                   0.0  Data Analytics
# 1            L                   0.0  Data Analytics
# 2            L                 100.0  Data Analytics
# 3            S                 100.0  Data Analytics
# 4            S                 100.0    Data Science

# %%
# Replacing UK with US
salaries['Employee_Location'] = salaries['Employee_Location'].str.replace('UK', 'US')

# %%
salaries.head()
# Out:
#    Working_Year       Designation Employment_Status Employee_Location  \
# 0        2020.0      Data Analyst                PT           Germany
# 1        2021.0  Business Analyst                FT                US
# 2        2023.0  Business Analyst          Contract                US
# 3        2021.0  Business Analyst                FT           Germany
# 4        2024.0    Data Scientist                FT               USA
#
#   Company_Size  Remote_Working_Ratio  Job_Categories
# 0            M                   0.0  Data Analytics
# 1            L                   0.0  Data Analytics
# 2            L                 100.0  Data Analytics
# 3            S                 100.0  Data Analytics
# 4            S                 100.0    Data Science

# %%
salaries = pd.read_csv(file_path+'/salary_data.csv')
salaries.head()
# Out:
#    Working_Year       Designation Experience Employment_Status  \
# 0        2020.0      Data Analyst       Lead                PT
# 1        2021.0  Business Analyst     Senior                FT
# 2        2023.0               NaN     Junior          Contract
# 3        2021.0  Business Analyst     Junior                FT
# 4        2024.0    Data Scientist       Lead                FT
#
#   Employee_Location Company_Size  Remote_Working_Ratio  Salary_USD
# 0           Germany            M                   0.0         NaN
# 1                UK            L                   0.0    53320.87
# 2                UK          NaN                 100.0         NaN
# 3           Germany            S                 100.0    55682.63
# 4               USA            S                 100.0    69469.78

# %%
salaries.groupby('Company_Size')['Salary_USD'].mean()
# Out:
# Company_Size
# L    146384.278403
# M    120331.502138
# S    132662.014643
# Name: Salary_USD, dtype: float64

# %%
# Adding summary statistics into a DataFrame
salaries['std_dev'] = salaries.groupby('Experience')['Salary_USD'].transform(lambda x: x.std())

# %%
print(salaries[['Experience', 'std_dev']].value_counts())
# Out:
# Experience  std_dev
# Junior      106582.800901    119
# Mid         102132.313623    118
# Lead        129329.767020    115
# Senior      140210.745849    100
# Name: count, dtype: int64

# %%
sns.boxplot(data=salaries, y='Salary_USD')
plt.show()

# %%
planes = pd.read_csv(file_path+'/palnes_data.csv')
planes.head()
# Out:
#        Airline Date_of_Journey    Source Destination            Route  \
# 0     SpiceJet      01/01/2023   Chennai   Hyderabad        BLR → DEL
# 1      Vistara      02/01/2023     Delhi   Hyderabad  CCU → MAA → COK
# 2  Jet Airways      03/01/2023  Banglore   Hyderabad  DEL → BOM → COK
# 3      Vistara      04/01/2023    Mumbai   Hyderabad        BLR → DEL
# 4      Vistara      05/01/2023    Mumbai     Kolkata  DEL → BOM → COK
#
#   Dep_Time Arrival_Time  Duration Total_Stops               Additional_Info  \
# 0  0:00:00      0:00:00      4.42      1 stop  No check-in baggage included
# 1  1:00:00      1:00:00      2.77    non-stop   In-flight meal not included
# 2  2:00:00      2:00:00      5.31     2 stops   In-flight meal not included
# 3  3:00:00      3:00:00      2.75      1 stop   In-flight meal not included
# 4  4:00:00      4:00:00      2.50     2 stops   In-flight meal not included
#
#       Price
# 0   3467.16
# 1   3432.23
# 2   5102.66
# 3  13401.24
# 4   6389.74

# %%
# correlation
sns.heatmap(planes.select_dtypes('number').corr(), annot=True, cmap='mako')
plt.show()

# %%
# Aggregated values with pd.crosstab()
pd.crosstab(planes["Source"], planes["Destination"], values=planes["Price"], aggfunc="median")
# Out:
# Destination     Cochin      Delhi  Hyderabad  Kolkata  New Delhi
# Source
# Banglore      8227.380   8184.970   8540.590  9386.36   7960.580
# Chennai       8239.370   9342.615   8687.050  7245.47   8595.720
# Delhi        10053.475   9200.380   6725.800  8796.48   7431.370
# Kolkata       9993.280   9287.535  13125.900  9426.65   8843.245
# Mumbai       10320.090  10855.810  10435.455  9075.31   8208.250

# %%
# cleaning total stops
planes['Total_Stops'] = planes['Total_Stops'].str.replace(" stops", "")
planes['Total_Stops'] = planes['Total_Stops'].str.replace(" stop", "")
planes['Total_Stops'] = planes['Total_Stops'].str.replace("non-stop", '0')
planes['Total_Stops'] = planes['Total_Stops'].astype(int)

# %%
planes.head()
# Out:
#        Airline Date_of_Journey    Source Destination            Route  \
# 0     SpiceJet      01/01/2023   Chennai   Hyderabad        BLR → DEL
# 1      Vistara      02/01/2023     Delhi   Hyderabad  CCU → MAA → COK
# 2  Jet Airways      03/01/2023  Banglore   Hyderabad  DEL → BOM → COK
# 3      Vistara      04/01/2023    Mumbai   Hyderabad        BLR → DEL
# 4      Vistara      05/01/2023    Mumbai     Kolkata  DEL → BOM → COK
#
#   Dep_Time Arrival_Time  Duration  Total_Stops               Additional_Info  \
# 0  0:00:00      0:00:00      4.42            1  No check-in baggage included
# 1  1:00:00      1:00:00      2.77            0   In-flight meal not included
# 2  2:00:00      2:00:00      5.31            2   In-flight meal not included
# 3  3:00:00      3:00:00      2.75            1   In-flight meal not included
# 4  4:00:00      4:00:00      2.50            2   In-flight meal not included
#
#       Price
# 0   3467.16
# 1   3432.23
# 2   5102.66
# 3  13401.24
# 4   6389.74

# %%
planes.dtypes
# Out:
# Airline             object
# Date_of_Journey     object
# Source              object
# Destination         object
# Route               object
# Dep_Time            object
# Arrival_Time        object
# Duration           float64
# Total_Stops          int64
# Additional_Info     object
# Price              float64
# dtype: object

# %%
planes['Date_of_Journey'] = pd.to_datetime(planes['Date_of_Journey'], dayfirst=True)

# %%
# Extracting month and weekday
planes["month"] = planes["Date_of_Journey"].dt.month
planes["weekday"] = planes["Date_of_Journey"].dt.weekday
print(planes[["month", "weekday", "Date_of_Journey"]].head())
# Out:
#    month  weekday Date_of_Journey
# 0      1        6      2023-01-01
# 1      1        0      2023-01-02
# 2      1        1      2023-01-03
# 3      1        2      2023-01-04
# 4      1        3      2023-01-05

# %%
planes.head()
# Out:
#        Airline Date_of_Journey    Source Destination            Route  \
# 0     SpiceJet      2023-01-01   Chennai   Hyderabad        BLR → DEL
# 1      Vistara      2023-01-02     Delhi   Hyderabad  CCU → MAA → COK
# 2  Jet Airways      2023-01-03  Banglore   Hyderabad  DEL → BOM → COK
# 3      Vistara      2023-01-04    Mumbai   Hyderabad        BLR → DEL
# 4      Vistara      2023-01-05    Mumbai     Kolkata  DEL → BOM → COK
#
#   Dep_Time Arrival_Time  Duration  Total_Stops               Additional_Info  \
# 0  0:00:00      0:00:00      4.42            1  No check-in baggage included
# 1  1:00:00      1:00:00      2.77            0   In-flight meal not included
# 2  2:00:00      2:00:00      5.31            2   In-flight meal not included
# 3  3:00:00      3:00:00      2.75            1   In-flight meal not included
# 4  4:00:00      4:00:00      2.50            2   In-flight meal not included
#
#       Price  month  weekday
# 0   3467.16      1        6
# ...

# %%
twenty_fifth = planes['Price'].quantile(0.25)
mid = planes['Price'].median()
sevety_fifth = planes['Price'].quantile(0.75)
max = planes['Price'].max()
print(twenty_fifth)
print(mid)
print(sevety_fifth)
print(max)
# Out:
# 6004.077499999999
# 9075.33
# 11792.4925
# 14966.19

# %%
# creating new categorical column
bins = [0, twenty_fifth, mid, sevety_fifth, max]
labels = ["Economy","Premium Economy", "Business Class", "First Class"]
planes['Price_Category'] = pd.cut(planes['Price'], bins=bins, labels=labels)

# %%
planes.head()
# Out:
#        Airline Date_of_Journey    Source Destination            Route  \
# 0     SpiceJet      2023-01-01   Chennai   Hyderabad        BLR → DEL
# 1      Vistara      2023-01-02     Delhi   Hyderabad  CCU → MAA → COK
# 2  Jet Airways      2023-01-03  Banglore   Hyderabad  DEL → BOM → COK
# 3      Vistara      2023-01-04    Mumbai   Hyderabad        BLR → DEL
# 4      Vistara      2023-01-05    Mumbai     Kolkata  DEL → BOM → COK
#
#   Dep_Time Arrival_Time  Duration  Total_Stops               Additional_Info  \
# 0  0:00:00      0:00:00      4.42            1  No check-in baggage included
# 1  1:00:00      1:00:00      2.77            0   In-flight meal not included
# 2  2:00:00      2:00:00      5.31            2   In-flight meal not included
# 3  3:00:00      3:00:00      2.75            1   In-flight meal not included
# 4  4:00:00      4:00:00      2.50            2   In-flight meal not included
#
#       Price  month  weekday   Price_Category
# ...

# %%
sns.countplot(data=planes, x='Airline', hue='Price_Category')
# Out:
# <Axes: xlabel='Airline', ylabel='count'>

# %%
sns.heatmap(planes.select_dtypes('number').corr(), annot=True, cmap='YlGnBu')
plt.show()

# %%
# Spurious correlation
sns.scatterplot(data=planes, y='Price', x='Duration', palette='deep',hue='Total_Stops')
plt.show()
