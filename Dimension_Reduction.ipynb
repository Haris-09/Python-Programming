# %% [markdown]
# <a href="https://colab.research.google.com/github/Haris-09/Python-Programming/blob/main/Dimension_Reduction.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

data = {'Name': ['Bulbasaur', 'Ivysaur', 'Venusaur', 'Charmander', 'Charmeleon'],
        'Type': ['Grass', 'Grass', 'Grass', 'Fire', 'Fire'],
        'HP': [45, 60, 80, 39, 68],
        'Attack': [49, 62, 82, 52, 64],
        'Defense': [49, 63, 83, 43, 58],
        'Speed': [45, 60, 80, 65, 80],
        'Generation': [1, 1, 1, 1, 1]}
df = pd.DataFrame(data)
display(df)
# Out:
#          Name   Type  HP  Attack  Defense  Speed  Generation
# 0   Bulbasaur  Grass  45      49       49     45           1
# 1     Ivysaur  Grass  60      62       63     60           1
# 2    Venusaur  Grass  80      82       83     80           1
# 3  Charmander   Fire  39      52       43     65           1
# 4  Charmeleon   Fire  68      64       58     80           1

# %%
df.describe(exclude='number')
# Out:
#              Name   Type
# count           5      5
# unique          5      2
# top     Bulbasaur  Grass
# freq            1      3

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
file_path = '/content/drive/My Drive/NAVTCC: Data Science & AI' # Replace with your file path
pokemon = pd.read_csv(file_path+'/pokemon.csv')
pokemon.head()
# Out:
#    #                   Name Type 1  Type 2  Total  HP  Attack  Defense  \
# 0  1              Bulbasaur  Grass  Poison    318  45      49       49
# 1  2                Ivysaur  Grass  Poison    405  60      62       63
# 2  3               Venusaur  Grass  Poison    525  80      82       83
# 3  3  VenusaurMega Venusaur  Grass  Poison    625  80     100      123
# 4  4             Charmander   Fire     NaN    309  39      52       43
#
#    Sp. Atk  Sp. Def  Speed  Generation  Legendary
# 0       65       65     45           1      False
# 1       80       80     60           1      False
# 2      100      100     80           1      False
# 3      122      120     80           1      False
# 4       60       50     65           1      False

# %%
pokemon.set_index('Name', inplace=True)
pokemon.loc['Charmander']
# Out:
# #                 4
# Type 1         Fire
# Type 2          NaN
# Total           309
# HP               39
# Attack           52
# Defense          43
# Sp. Atk          60
# Sp. Def          50
# Speed            65
# Generation        1
# Legendary     False
# Name: Charmander, dtype: object

# %%
df2 = pokemon.describe()

# %%
display(df2)
# Out:
#                 #      Total          HP      Attack     Defense     Sp. Atk  \
# count  800.000000  800.00000  800.000000  800.000000  800.000000  800.000000
# mean   362.813750  435.10250   69.258750   79.001250   73.842500   72.820000
# std    208.343798  119.96304   25.534669   32.457366   31.183501   32.722294
# min      1.000000  180.00000    1.000000    5.000000    5.000000   10.000000
# 25%    184.750000  330.00000   50.000000   55.000000   50.000000   49.750000
# 50%    364.500000  450.00000   65.000000   75.000000   70.000000   65.000000
# 75%    539.250000  515.00000   80.000000  100.000000   90.000000   95.000000
# max    721.000000  780.00000  255.000000  190.000000  230.000000  194.000000
#
#           Sp. Def       Speed  Generation
# count  800.000000  800.000000   800.00000
# mean    71.902500   68.277500     3.32375
# std     27.828916   29.060474     1.66129
# min     20.000000    5.000000     1.00000
# 25%     50.000000   45.000000     2.00000
# ...

# %%
df2['Total']
# Out:
# count    800.00000
# mean     435.10250
# std      119.96304
# min      180.00000
# 25%      330.00000
# 50%      450.00000
# 75%      515.00000
# max      780.00000
# Name: Total, dtype: float64

# %%
df2.loc['std']
# Out:
# #             208.343798
# Total         119.963040
# HP             25.534669
# Attack         32.457366
# Defense        31.183501
# Sp. Atk        32.722294
# Sp. Def        27.828916
# Speed          29.060474
# Generation      1.661290
# Name: std, dtype: float64

# %%
df2.loc['std']<=2
# Out:
# #             False
# Total         False
# HP            False
# Attack        False
# Defense       False
# Sp. Atk       False
# Sp. Def       False
# Speed         False
# Generation     True
# Name: std, dtype: bool

# %%
col_to_remove = df2.loc['std']<=2

# %%
df2.drop(columns=col_to_remove[col_to_remove].index, inplace=True)

# %%
display(df2)
# Out:
#                 #      Total          HP      Attack     Defense     Sp. Atk  \
# count  800.000000  800.00000  800.000000  800.000000  800.000000  800.000000
# mean   362.813750  435.10250   69.258750   79.001250   73.842500   72.820000
# std    208.343798  119.96304   25.534669   32.457366   31.183501   32.722294
# min      1.000000  180.00000    1.000000    5.000000    5.000000   10.000000
# 25%    184.750000  330.00000   50.000000   55.000000   50.000000   49.750000
# 50%    364.500000  450.00000   65.000000   75.000000   70.000000   65.000000
# 75%    539.250000  515.00000   80.000000  100.000000   90.000000   95.000000
# max    721.000000  780.00000  255.000000  190.000000  230.000000  194.000000
#
#           Sp. Def       Speed
# count  800.000000  800.000000
# mean    71.902500   68.277500
# std     27.828916   29.060474
# min     20.000000    5.000000
# 25%     50.000000   45.000000
# 50%     70.000000   65.000000
# 75%     90.000000   90.000000
# ...

# %%
ansur = pd.read_csv(file_path+'/ansur.csv', encoding='latin-1')
ansur.head()
# Out:
#    subjectid  abdominalextensiondepthsitting  acromialheight  \
# 0      10027                             266            1467
# 1      10032                             233            1395
# 2      10033                             287            1430
# 3      10092                             234            1347
# 4      10093                             250            1585
#
#    acromionradialelength  anklecircumference  axillaheight  \
# 0                    337                 222          1347
# 1                    326                 220          1293
# 2                    341                 230          1327
# 3                    310                 230          1239
# 4                    372                 247          1478
#
#    balloffootcircumference  balloffootlength  biacromialbreadth  \
# 0                      253               202                401
# 1                      245               193                394
# ...

# %%
df2 = ansur.describe()
display(df2)
# Out:
#           subjectid  abdominalextensiondepthsitting  acromialheight  \
# count   4082.000000                     4082.000000     4082.000000
# mean   20003.370897                      254.650906     1440.736894
# std     6568.435122                       37.327178       63.287242
# min    10027.000000                      163.000000     1194.000000
# 25%    14270.250000                      227.000000     1398.000000
# 50%    17236.500000                      251.000000     1439.000000
# 75%    27315.750000                      279.000000     1481.000000
# max    29452.000000                      451.000000     1683.000000
#
#        acromionradialelength  anklecircumference  axillaheight  \
# count            4082.000000         4082.000000   4082.000000
# mean              335.244488          229.343949   1329.082068
# std                17.482795           14.649102     59.516123
# min               270.000000          156.000000   1106.000000
# ...

# %%
col_to_remove = df2.loc['std']<=10
display(col_to_remove)
# Out:
# subjectid                         False
# abdominalextensiondepthsitting    False
# acromialheight                    False
# acromionradialelength             False
# anklecircumference                False
#                                   ...
# SubjectNumericRace                False
# DODRace                            True
# Age                                True
# Heightin                           True
# Weightlbs                         False
# Name: std, Length: 99, dtype: bool

# %%
df2.drop(columns=col_to_remove[col_to_remove].index, inplace=True)
display(df2)
# Out:
#           subjectid  abdominalextensiondepthsitting  acromialheight  \
# count   4082.000000                     4082.000000     4082.000000
# mean   20003.370897                      254.650906     1440.736894
# std     6568.435122                       37.327178       63.287242
# min    10027.000000                      163.000000     1194.000000
# 25%    14270.250000                      227.000000     1398.000000
# 50%    17236.500000                      251.000000     1439.000000
# 75%    27315.750000                      279.000000     1481.000000
# max    29452.000000                      451.000000     1683.000000
#
#        acromionradialelength  anklecircumference  axillaheight  \
# count            4082.000000         4082.000000   4082.000000
# mean              335.244488          229.343949   1329.082068
# std                17.482795           14.649102     59.516123
# min               270.000000          156.000000   1106.000000
# ...
